# %% [markdown]
# <h1 style="color:#081c15"><b>Pandas Data Frame</b></h1>
# <hr style="color:#081c15">

# %% [markdown]
# <h4 style="color:#081c15"><b>Pandas Data Frame</b></h4>
#
#  - A Pandas data frame is like a table. It is a 2-D array holding data of any type.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h4 style="color:#081c15"><b>Make Pandas Dataframe Using Python Differnt Objects</b></h4>

# %% [markdown]
# <ul style="color:red"><li><b>Using List</b></li></ul>

# %%
studentsList=[[100,20,145],[90,22,113],[71,18,180],[32,27,110]]
df=pd.DataFrame(studentsList,columns=['marks','age','iq'])
df
# Out:
#    marks  age   iq
# 0    100   20  145
# 1     90   22  113
# 2     71   18  180
# 3     32   27  110

# %% [markdown]
# <ul style="color:red"><li><b>Using Dictionary</b></li></ul>

# %%
studentsDict={
    'name':['Tayyab','Ali','Ahmad','Bisma'],
    'marks':[100,90,71,32],
    'age':[20,18,22,25]
}

df=pd.DataFrame(studentsDict)
df
# Out:
#      name  marks  age
# 0  Tayyab    100   20
# 1     Ali     90   18
# 2   Ahmad     71   22
# 3   Bisma     32   25

# %% [markdown]
# <ul style="color:red"><li><b>Using CSV File</b></li></ul>

# %%
movies=pd.read_csv("movies.csv")
# movies
ipl=pd.read_csv("ipl-matches.csv")
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# <h4 style="color:#081c15"><b>Dataframe Attributes</b></h4>

# %% [markdown]
# <ul style="color:red"><li><b>shape</b></li></ul>

# %%
movies.shape
# Out:
# (1629, 18)

# %% [markdown]
# <ul style="color:red"><li><b>dtypes</b></li></ul>

# %%
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %% [markdown]
# <ul style="color:red"><li><b>index</b></li></ul>

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %% [markdown]
# <ul style="color:red"><li><b>columns</b></li></ul>

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %% [markdown]
# <ul style="color:red"><li><b>values</b></li></ul>

# %%
movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %% [markdown]
# <h4 style="color:#081c15"><b>Dataframe Methods</b></h4>

# %% [markdown]
# <ul style="color:red"><li><b>head</b></li></ul>

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %% [markdown]
# <ul style="color:red"><li><b>tail</b></li></ul>

# %%
movies.tail()
# Out:
#                     title_x     imdb_id  \
# 1624  Tera Mera Saath Rahen   tt0301250
# 1625   Yeh Zindagi Ka Safar   tt0298607
# 1626        Sabse Bada Sukh   tt0069204
# 1627                  Daaka  tt10833860
# 1628               Humsafar   tt2403201
#
#                                             poster_path  \
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar
#
# ...

# %% [markdown]
# <ul style="color:red"><li><b>sample</b></li></ul>

# %%
movies.sample(2)
# Out:
#                  title_x    imdb_id  \
# 237          Rukh (film)  tt7341406
# 1154  Aryan: Unbreakable  tt0454396
#
#                                             poster_path  \
# 237   https://upload.wikimedia.org/wikipedia/en/thum...
# 1154  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link             title_y  \
# 237          https://en.wikipedia.org/wiki/Rukh_(film)                Rukh
# 1154  https://en.wikipedia.org/wiki/Aryan:_Unbreakable  Aryan: Unbreakable
#
#           original_title  is_adult  year_of_release runtime  \
# 237                 Rukh         0             2017     106
# 1154  Aryan: Unbreakable         0             2006     135
#
#                   genres  imdb_rating  imdb_votes  \
# 237        Drama|Mystery          6.4         383
# 1154  Action|Drama|Sport          4.5         283
#
#                                                   story  \
# ...

# %% [markdown]
# <ul style="color:red"><li><b>info</b></li></ul>

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %% [markdown]
# <ul style="color:red"><li><b>describe</b></li></ul>

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %% [markdown]
# <ul style="color:red"><li><b>isnull</b></li></ul>

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %% [markdown]
# <ul style="color:red"><li><b>duplicated</b></li></ul>

# %%
movies.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <ul style="color:red"><li><b>rename</b></li></ul>

# %%
movies.rename(columns={'wins_nominations':'wins_Nomination','runtime':'runTime'},inplace=True)

# %% [markdown]
# <ul style="color:red"><li><b>astype</b></li></ul>

# %%
movies['is_adult']=movies['is_adult'].astype('bool')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title_x          1629 non-null   object
#  1   imdb_id          1629 non-null   object
#  2   poster_path      1526 non-null   object
#  3   wiki_link        1629 non-null   object
#  4   title_y          1629 non-null   object
#  5   original_title   1629 non-null   object
#  6   is_adult         1629 non-null   bool
#  7   year_of_release  1629 non-null   int64
#  8   runTime          1629 non-null   object
#  9   genres           1629 non-null   object
#  10  imdb_rating      1629 non-null   float64
#  11  imdb_votes       1629 non-null   int64
#  12  story            1609 non-null   object
#  13  summary          1629 non-null   object
#  14  tagline          557 non-null    object
#  15  actors           1624 non-null   object
# ...

# %% [markdown]
# <h4 style="color:#081c15"><b>Other Dataframe Important work</b></h4>

# %% [markdown]
# <ul style="color:red"><li><b>Selection of a Single column</b></li></ul>

# %%
movies['actors']
# Out:
# 0       Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1       Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2       Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3       Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4       Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
#                               ...
# 1624    Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625    Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626    Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                            Gippy Grewal|Zareen Khan|
# 1628                                          Fawad Khan|
# Name: actors, Length: 1629, dtype: object

# %% [markdown]
# <ul style="color:red"><li><b>Selection of multiple columns</b></li></ul>

# %%
movies[['actors','runTime']]
# Out:
#                                                  actors runTime
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...     138
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...     131
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...     112
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...     121
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...     102
# ...                                                 ...     ...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...     148
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...     146
# 1626  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...      \N
# 1627                          Gippy Grewal|Zareen Khan|     136
# 1628                                        Fawad Khan|      35
#
# [1629 rows x 2 columns]

# %% [markdown]
# <ul style="color:red"><li><b>Selection of a single row</b></li></ul>

# %%
movies.iloc[0]
# Out:
# title_x                                     Uri: The Surgical Strike
# imdb_id                                                    tt8291224
# poster_path        https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link          https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                     Uri: The Surgical Strike
# original_title                              Uri: The Surgical Strike
# is_adult                                                       False
# year_of_release                                                 2019
# runTime                                                          138
# genres                                              Action|Drama|War
# imdb_rating                                                      8.4
# imdb_votes                                                     35112
# story              Divided over five chapters  the film chronicle...
# summary            Indian army special forces execute a covert op...
# ...

# %%
# Another method
movies.loc[0:50:20]
# Out:
#                       title_x    imdb_id  \
# 0    Uri: The Surgical Strike  tt8291224
# 20  Mere Pyare Prime Minister  tt8207768
# 40            Super 30 (film)  tt7485048
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 20  https://upload.wikimedia.org/wikipedia/en/thum...
# 40  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 0   https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 20  https://en.wikipedia.org/wiki/Mere_Pyare_Prime...
# 40      https://en.wikipedia.org/wiki/Super_30_(film)
#
#                       title_y             original_title  is_adult  \
# 0    Uri: The Surgical Strike   Uri: The Surgical Strike     False
# 20  Mere Pyare Prime Minister  Mere Pyare Prime Minister     False
# 40                   Super 30                   Super 30     False
#
#     year_of_release runTime            genres  imdb_rating  imdb_votes  \
# ...

# %% [markdown]
# <ul style="color:red"><li><b>Selection of multiple rows</b></li></ul>

# %%
movies.iloc[0:5:2] # third paramter is for steps
movies.iloc[[0,2,9]] # third paramter is for steps
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 2  The Accidental Prime Minister (film)  tt6986710
# 9                      Thackeray (film)  tt7777196
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 9  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 9     https://en.wikipedia.org/wiki/Thackeray_(film)
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike     False
# 2  The Accidental Prime Minister  The Accidental Prime Minister     False
# 9                      Thackeray                      Thackeray     False
#
# ...

# %% [markdown]
# <ul style="color:red"><li><b>Selection of multiple rows and columns</b></li></ul>

# %%
movies.iloc[0:5,0:2]      
# While using iloc We always provide index of columns and slicing last part is excluded
movies.loc[0:5,['title_x','imdb_id']]
# While using loc We can provide index of columns  and name of columns as well while slicing last part is included
# Out:
#                                 title_x    imdb_id
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866

# %% [markdown]
# <ul style="color:red"><li><b>Adding of New Columns</b></li></ul>

# %%
ipl['country']='india'

# %% [markdown]
# <h4 style="color:#081c15"><b>Data Filtering</b></h4>

# %% [markdown]
# <ul style="color:red"><li><b>Find all the final winners</b></li></ul>

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field  ...
#
#         WinningTeam    WonBy Margin  method Player_of_Match  \
# 0    Gujarat Titans  Wickets    7.0     NaN       HH Pandya
# 1  Rajasthan Royals  Wickets    7.0     NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1  \
# ...

# %%
# index=ipl['MatchNumber']=='Final'
# winners=ipl[index]
# winners[['Season','WinningTeam']]


# other metod
ipl[ipl['MatchNumber']=='Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %% [markdown]
# <ul style="color:red"><li><b>How many super over finishes have occured</b></li></ul>

# %%
ipl[ipl['SuperOver']=='Y'].shape[0]
# Out:
# 14

# %% [markdown]
# <ul style="color:red"><li><b>How many matches has csk won in kolkata</b></li></ul>

# %%
ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=='Chennai Super Kings')].shape[0]
# Out:
# 5

# %% [markdown]
# <ul style="color:red"><li><b>Toss winner is match winner in percentage</b></li></ul>

# %%
ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0] / ipl.shape[0]*100
# Out:
# 51.473684210526315

# %% [markdown]
# <ul style="color:red"><li><b>Movies with rating higher than 8 and votes>10000</b></li></ul>

# %%
movies[(movies['imdb_rating']>8.0) & (movies['imdb_votes']>10000)].shape[0]
# Out:
# 43

# %% [markdown]
# <ul style="color:red"><li><b>Action movies with rating higher than 7.5</b></li></ul>

# %%
# movies[(movies['genres'].str.contains('Action')) & (movies['imdb_rating']>7.5)].shape[0]
#other way
movies[(movies['genres'].str.split('|').apply(lambda x:'Action' in x)) & (movies['imdb_rating']>7.5)].shape[0]
# Out:
# 33

# %% [markdown]
# <ul style="color:red"><li><b>Write a function that can return the track record of 2 teams against each other</b></li></ul>

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
def teams2Winners(x,y):
    count1=movies[movies['WinningTeam']==x].shape[0]
    count2=movies[movies['WinningTeam']==y].shape[0]
    return (count1,count2)
   
   
ipl 

hello=teams2Winners('Rajasthan Royals','Gujarat Titans')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/python_eda/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WinningTeam'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>U</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>Using Dictionary</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>Using Dictionary</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>Using Dictionary</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>Using Dictionary</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>Using Dictionary</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>Using Dictionary</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>Using Dictionary</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>Using Dictionary</b></li></ul>

# %% [markdown]
# <ul style="color:red"><li><b>Using Dictionary</b></li></ul>
